# %% [markdown]
# # Caitlyn Clark's Perfromance in Womens College Basketball
#
# ### Presented by: Bladimir Nunez
# ### Updated: April 1, 2024

# %% [markdown]
# ## Project Overview
# Many Consider Caitlyn Clark who is currently a guard for the Iowa Hawkeyes womens basketball team to be the greatest player ever in womens basketball thus far. But with every great thing theres always the bad. With her fans there are also critics who think because Caitlyn Clark currently leads D1 womens basketball in scoring that she is considered a "ball-hog" which indicates she never passes the ball to her teammates. This project will compare Caitlyn Clark and other women basketball players in division 1 in scoring and assists so far this year. As I compare the scoring to assists ratio I will want to prove that she is not a "ball-hog" and indeed passes the ball to her teammates and still is efficient herself with her scoring capabilities.
#
# 1.) Prove that Caitlyn Clark is not indeed a "ball-hog" but an efficient scorer and passer

# %% [markdown]
# ## Import Libaries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# ## Gather Data Needed For Analysis

# %%
# gather data from NCAA website for top 10 scorers in points per game
points_per_game_url = 'https://www.ncaa.com/stats/basketball-women/d1'
points_per_game_req = requests.get(points_per_game_url)
soup = BeautifulSoup(points_per_game_req.text, 'html')

# %%
# Get points per game table
points_table = soup.find('table')

# Access the titles in points per game table
points_titles = points_table.find_all('th')
titles = [title.text.strip() for title in points_titles]


# get each row in table
points_column_data = points_table.find_all('tr')

# Create dataframe for points table
df = pd.DataFrame(columns = titles)


for row in points_column_data[1:]:
    row_data = row.find_all('td')
    rows = [data.text.strip() for data in row_data]
   
    
    
    length = len(df)
    df.loc[length] = rows

# %%
# Access all assists pages URLS
assists_per_game_url_one = 'https://www.ncaa.com/stats/basketball-women/d1/current/individual/106'
assists_per_game_url_two = 'https://www.ncaa.com/stats/basketball-women/d1/current/individual/106/p2'
assists_per_game_url_three = 'https://www.ncaa.com/stats/basketball-women/d1/current/individual/106/p3'
assists_per_game_url_four = 'https://www.ncaa.com/stats/basketball-women/d1/current/individual/106/p4'
assists_per_game_url_five = 'https://www.ncaa.com/stats/basketball-women/d1/current/individual/106/p5'

# create request to each URL and make Soup object
assists_req_one = requests.get(assists_per_game_url_one)
assists_req_two = requests.get(assists_per_game_url_two)
assists_req_three = requests.get(assists_per_game_url_three)
assists_req_four = requests.get(assists_per_game_url_four)
assists_req_five = requests.get(assists_per_game_url_five)

# soup objects for each page
soup_assists_one = BeautifulSoup(assists_req_one.text, 'html')
soup_assists_two = BeautifulSoup(assists_req_two.text, 'html')
soup_assists_three = BeautifulSoup(assists_req_three.text, 'html')
soup_assists_four = BeautifulSoup(assists_req_four.text, 'html')
soup_assists_five = BeautifulSoup(assists_req_five.text, 'html')

# %%
# find tables on each page
first_table = soup_assists_one.find('table')
second_table = soup_assists_two.find('table')
third_table = soup_assists_three.find('table')
fourth_table = soup_assists_four.find('table')
fifth_table = soup_assists_five.find('table')

# First table titles
first_titles = first_table.find_all('th')
first_title = [title.text.strip() for title in first_titles]

# get table rows from all pages
first_column_data = first_table.find_all('tr')
second_column_data = second_table.find_all('tr')
third_column_data = third_table.find_all('tr')
fourth_column_data = fourth_table.find_all('tr')
fifth_column_data = fifth_table.find_all('tr')

# Create dataframe for assists table
assists_df = pd.DataFrame(columns = first_title )

# add first page of assists to df
for row_assist in first_column_data[1:]:
    one = row_assist.find_all('td')
    one_rows = [row.text.strip() for row in one]
    
    length = len(assists_df)
    assists_df.loc[length] = one_rows

# add second page of assists to df
for row_assist in second_column_data[1:]:
    two = row_assist.find_all('td')
    two_rows = [row.text.strip() for row in two]
    
    length = len(assists_df)
    assists_df.loc[length] = two_rows

# add third page of assists to df
for row_assist in third_column_data[1:]:
    three = row_assist.find_all('td')
    three_rows = [row.text.strip() for row in three]
    
    length = len(assists_df)
    assists_df.loc[length] = three_rows


# add fourth page of assists to df
for row_assist in fourth_column_data[1:]:
    four = row_assist.find_all('td')
    four_rows = [row.text.strip() for row in four]
    
    length = len(assists_df)
    assists_df.loc[length] = four_rows
    
# add fifth page of assists to df
for row_assist in fifth_column_data[1:]:
    five = row_assist.find_all('td')
    five_rows = [row.text.strip() for row in five]
    
    length = len(assists_df)
    assists_df.loc[length] = five_rows

# %%
pd.set_option("display.max_rows", None)

# %% [markdown]
# ## Combine Dataframes into One

# %%
merge_df = pd.merge(df,assists_df, on='Name', how='outer')
merge_df
# Out:
#     Rank_x                     Name               Team_x   PPG Rank_y  \
# 0        1            Caitlin Clark                 Iowa  31.7      1
# 1        2             JuJu Watkins  Southern California  27.0      -
# 2        3               Lucy Olsen            Villanova  23.4    141
# 3        4           Chellia Watson              Buffalo  23.0      -
# 4        5         Elizabeth Kitley        Virginia Tech  22.8    NaN
# 5        6           Hannah Hidalgo           Notre Dame  22.6     24
# 6        7             Rachael Rose              Wofford  22.3     28
# 7        8             Dyaisha Fair             Syracuse  22.2    173
# 8        9        Izzy Higginbottom         Arkansas St.  22.2    156
# 9       10        McKenna Hofschild         Colorado St.  22.1      2
# 10     NaN          Katie Dinnebier                  NaN   NaN      3
# 11     NaN           Georgia Amoore                  NaN   NaN      4
# 12     NaN          Benthe Versteeg                  NaN   NaN      5
# 13     NaN             Mama Dembele                  NaN   NaN      6
# 14     NaN                Nika Muhl                  NaN   NaN      7
# 15     NaN              Abby Beeman                  NaN   NaN      8
# 16     NaN           Julia Martinez                  NaN   NaN      9
# 17     NaN              Jenna Clark                  NaN   NaN     10
# 18     NaN         Lauren Park-Lane                  NaN   NaN     11
# 19     NaN             Jeanae Terry                  NaN   NaN     12
# 20     NaN             Anaya  James                  NaN   NaN     13
# 21     NaN              Ines Vieira                  NaN   NaN     14
# 22     NaN              Kaylah Ivey                  NaN   NaN     15
# 23     NaN          Kaylynne Truong                  NaN   NaN     16
# 24     NaN      Jenna Annecchiarico                  NaN   NaN     17
# 25     NaN              Jaz Shelley                  NaN   NaN     18
# 26     NaN               Zaay Green                  NaN   NaN     19
# 27     NaN           Ashley Hawkins                  NaN   NaN     20
# 28     NaN             Caroline Lau                  NaN   NaN     21
# 29     NaN              Jamie Loera                  NaN   NaN     22
# 30     NaN           Serena Sundell                  NaN   NaN      -
# 31     NaN          Shyanne Sellers                  NaN   NaN     25
# 32     NaN             Amaya Battle                  NaN   NaN     26
# 33     NaN            Bailey Butler                  NaN   NaN     27
# 34     NaN           Kymora Johnson                  NaN   NaN     29
# 35     NaN             Amari Wright                  NaN   NaN     30
# 36     NaN          Denim DeShields                  NaN   NaN     31
# 37     NaN          Jordan Harrison                  NaN   NaN     32
# 38     NaN           Grace Townsend                  NaN   NaN     33
# 39     NaN          DeeDee Hagemann                  NaN   NaN     34
# 40     NaN             Tonie Morgan                  NaN   NaN     35
# 41     NaN             Elisa Mevius                  NaN   NaN     36
# 42     NaN             Miah Monahan                  NaN   NaN     37
# 43     NaN         Veronica Sheffey                  NaN   NaN     38
# 44     NaN           Jaylyn Sherrod                  NaN   NaN     39
# 45     NaN       Dayshanette Harris                  NaN   NaN     40
# 46     NaN         Savannah Wheeler                  NaN   NaN     41
# 47     NaN           Madison Booker                  NaN   NaN     42
# 48     NaN      Talia von Oelhoffen                  NaN   NaN      -
# 49     NaN       Chloe Moore-McNeil                  NaN   NaN      -
# 50     NaN            Grace Larkins                  NaN   NaN     45
# 51     NaN                Tess Heal                  NaN   NaN     46
# 52     NaN             Kaitlyn Chen                  NaN   NaN     47
# 53     NaN            Raven Johnson                  NaN   NaN     48
# 54     NaN         Leilani McIntosh                  NaN   NaN     49
# 55     NaN               Kyra White                  NaN   NaN     50
# 56     NaN          Trinity Johnson                  NaN   NaN     51
# 57     NaN               Ally Becki                  NaN   NaN     52
# 58     NaN               Addy Brown                  NaN   NaN     53
# 59     NaN            Gigi Gonzalez                  NaN   NaN      -
# 60     NaN          Shaulana Wagner                  NaN   NaN     55
# 61     NaN             Kamy Peppler                  NaN   NaN     56
# 62     NaN             Nyla Hampton                  NaN   NaN     57
# 63     NaN            Kiara Jackson                  NaN   NaN     58
# 64     NaN               Rose Nkumu                  NaN   NaN     59
# 65     NaN              Amy Velasco                  NaN   NaN     60
# 66     NaN           Adrianna Smith                  NaN   NaN     61
# 67     NaN             Faith Alston                  NaN   NaN     62
# 68     NaN            Aerial Wilson                  NaN   NaN     63
# 69     NaN              Lacy Stokes                  NaN   NaN     64
# 70     NaN            Anna Gret Asi                  NaN   NaN     65
# 71     NaN             Sophia Wiard                  NaN   NaN     66
# 72     NaN          Nae Nae Calhoun                  NaN   NaN     67
# 73     NaN          Megan McConnell                  NaN   NaN     68
# 74     NaN               Nevaeh Tot                  NaN   NaN     69
# 75     NaN        Crystal Henderson                  NaN   NaN     70
# 76     NaN          Ny'Ceara  Pryor                  NaN   NaN     71
# 77     NaN            Jordan Hodges                  NaN   NaN     72
# 78     NaN              Jadyn Weltz                  NaN   NaN     73
# 79     NaN                Kiki Rice                  NaN   NaN     74
# 80     NaN         Jordyn Cambridge                  NaN   NaN     75
# 81     NaN        Kaitlyn  Flanagan                  NaN   NaN     76
# 82     NaN          Kayleigh Truong                  NaN   NaN     77
# 83     NaN            Derin Erdogan                  NaN   NaN     78
# 84     NaN             Asia Avinger                  NaN   NaN     79
# 85     NaN       Bria Sanders-Woods                  NaN   NaN     80
# 86     NaN              Luana Leite                  NaN   NaN     81
# 87     NaN            Filipa Barros                  NaN   NaN      -
# 88     NaN          Daisha Bradford                  NaN   NaN     83
# 89     NaN              Makira Cook                  NaN   NaN     84
# 90     NaN           Harmoni Turner                  NaN   NaN     85
# 91     NaN            Mary Kay Naro                  NaN   NaN     86
# 92     NaN         Mackenzie Amalia                  NaN   NaN     87
# 93     NaN            Kelsey Ransom                  NaN   NaN     88
# 94     NaN           Molly Mogensen                  NaN   NaN     89
# 95     NaN           Jasmine Powell                  NaN   NaN      -
# 96     NaN           Alice Recanati                  NaN   NaN     91
# 97     NaN          Sara Wohlgemuth                  NaN   NaN     92
# 98     NaN            Ronnie Porter                  NaN   NaN     93
# 99     NaN             Aleah Nelson                  NaN   NaN     94
# 100    NaN                Maya Wong                  NaN   NaN     95
# 101    NaN           Ta'Niya Latson                  NaN   NaN     96
# 102    NaN             Anala Nelson                  NaN   NaN     97
# 103    NaN             Tate Walters                  NaN   NaN     98
# 104    NaN            Hannah Cooper                  NaN   NaN     99
# 105    NaN              Alexis Mead                  NaN   NaN      -
# 106    NaN            Talana Lepolo                  NaN   NaN    101
# 107    NaN             Colbi Maples                  NaN   NaN    102
# 108    NaN         Veronica Charles                  NaN   NaN    103
# 109    NaN           Jayden Marable                  NaN   NaN    104
# 110    NaN          Kitty Henderson                  NaN   NaN    105
# 111    NaN              Paige Meyer                  NaN   NaN      -
# 112    NaN         Sam Galanopoulos                  NaN   NaN    107
# 113    NaN          Destini Lombard                  NaN   NaN    108
# 114    NaN         Charisma Osborne                  NaN   NaN      -
# 115    NaN              Niya Fields                  NaN   NaN      -
# 116    NaN             Quierra Love                  NaN   NaN    111
# 117    NaN             Sydney Gandy                  NaN   NaN    112
# 118    NaN          Payton Verhulst                  NaN   NaN    113
# 119    NaN          Douthsine Prien                  NaN   NaN    114
# 120    NaN        Avery Brittingham                  NaN   NaN    115
# 121    NaN           Reagan Bradley                  NaN   NaN    116
# 122    NaN          Cecelia Collins                  NaN   NaN      -
# 123    NaN          Tippy Robertson                  NaN   NaN      -
# 124    NaN               Tuti Jones                  NaN   NaN    119
# 125    NaN           Emma Utterback                  NaN   NaN      -
# 126    NaN            Sarah Andrews                  NaN   NaN    121
# 127    NaN            Kindyll Wetta                  NaN   NaN    122
# 128    NaN              Nitzan Amar                  NaN   NaN    123
# 129    NaN            Endyia Rogers                  NaN   NaN      -
# 130    NaN              Bella Earle                  NaN   NaN    125
# 131    NaN            Chloe Fleming                  NaN   NaN      -
# 132    NaN            Kaylah Rainey                  NaN   NaN      -
# 133    NaN             Jada  Burton                  NaN   NaN    128
# 134    NaN        JaMya Mingo-Young                  NaN   NaN      -
# 135    NaN          Keshuna Luckett                  NaN   NaN    130
# 136    NaN            Tanajah Hayes                  NaN   NaN    131
# 137    NaN  Kynidi Mason Striverson                  NaN   NaN    132
# 138    NaN           Paige Bueckers                  NaN   NaN    133
# 139    NaN              Gina Marxen                  NaN   NaN    134
# 140    NaN       Sandra Frau-Garcia                  NaN   NaN    135
# 141    NaN            Saniya Rivers                  NaN   NaN      -
# 142    NaN        Taleah Washington                  NaN   NaN    137
# 143    NaN           Lani Cornfield                  NaN   NaN    138
# 144    NaN             Jacy Sheldon                  NaN   NaN    139
# 145    NaN           Elise Williams                  NaN   NaN    140
# 146    NaN            Amari Whiting                  NaN   NaN      -
# 147    NaN            Brooke Mullin                  NaN   NaN    143
# 148    NaN           Kristian Young                  NaN   NaN      -
# 149    NaN        Colleen McQuillen                  NaN   NaN    145
# 150    NaN             Bella Runyan                  NaN   NaN    146
# 151    NaN         Taija Sta. Maria                  NaN   NaN      -
# 152    NaN            Kaylee Smiler                  NaN   NaN    148
# 153    NaN           Donovyn Hunter                  NaN   NaN    149
# 154    NaN  Izabela Nicoletti-Leite                  NaN   NaN    150
# 155    NaN            Peyton Carter                  NaN   NaN      -
# 156    NaN              Maraja Pass                  NaN   NaN      -
# 157    NaN           Te-Hina Paopao                  NaN   NaN    153
# 158    NaN             Diaba Konate                  NaN   NaN    154
# 159    NaN          Hailey Van Lith                  NaN   NaN      -
# 160    NaN            Aniyah Augmon                  NaN   NaN    157
# 161    NaN          Kaitlyn Zarycki                  NaN   NaN      -
# 162    NaN         Breanna Campbell                  NaN   NaN    159
# 163    NaN           Eleyana Tafisi                  NaN   NaN    160
# 164    NaN               Taina Mair                  NaN   NaN    161
# 165    NaN             Helena Pueyo                  NaN   NaN      -
# 166    NaN             Paige Kohler                  NaN   NaN    163
# 167    NaN               Lexi Rubel                  NaN   NaN      -
# 168    NaN                Ivy Bales                  NaN   NaN    165
# 169    NaN          Rana Elhusseini                  NaN   NaN    166
# 170    NaN              Jordan King                  NaN   NaN    167
# 171    NaN             Ally Knights                  NaN   NaN      -
# 172    NaN            Janelle Brown                  NaN   NaN    169
# 173    NaN             Alyssa Ustby                  NaN   NaN      -
# 174    NaN          Daylani Ballena                  NaN   NaN    171
# 175    NaN              Katie Novik                  NaN   NaN      -
# 176    NaN            Ashley Austin                  NaN   NaN    174
# 177    NaN      Shayeann Day-Wilson                  NaN   NaN    175
# 178    NaN           Maya McDermott                  NaN   NaN      -
# 179    NaN          Ayanna Khalfani                  NaN   NaN    177
# 180    NaN           Kiyley Flowers                  NaN   NaN    178
# 181    NaN      Trinity San Antonio                  NaN   NaN      -
# 182    NaN           Tilda Sjökvist                  NaN   NaN    180
# 183    NaN               Kyah Smith                  NaN   NaN    181
# 184    NaN         Marley Washenitz                  NaN   NaN      -
# 185    NaN            Ber'Nyah Mayo                  NaN   NaN    183
# 186    NaN          Destiny Jackson                  NaN   NaN    184
# 187    NaN             McKelle Meek                  NaN   NaN      -
# 188    NaN            Dena Jarrells                  NaN   NaN      -
# 189    NaN          Addi Brownfield                  NaN   NaN      -
# 190    NaN       Molly Masciantonio                  NaN   NaN      -
# 191    NaN                Anne Bair                  NaN   NaN      -
# 192    NaN           Samara Spencer                  NaN   NaN    190
# 193    NaN             Chloe Hodges                  NaN   NaN    191
# 194    NaN        Samantha Johnston                  NaN   NaN    192
# 195    NaN               Emma Smith                  NaN   NaN      -
# 196    NaN          Mikyla Tolivert                  NaN   NaN    194
# 197    NaN            Astera Tuhina                  NaN   NaN      -
# 198    NaN               Zoe Brooks                  NaN   NaN    196
# 199    NaN            Jordyn Dorsey                  NaN   NaN    197
# 200    NaN            Maddie Scherr                  NaN   NaN    198
# 201    NaN     Kylie Kornegay-Lucas                  NaN   NaN    199
# 202    NaN              Gemma Nunez                  NaN   NaN      -
# 203    NaN            Anaiyah Tu'ua                  NaN   NaN      -
# 204    NaN             Laila Jewett                  NaN   NaN    202
# 205    NaN                 Ivy Wolf                  NaN   NaN      -
# 206    NaN           Kacie Borowicz                  NaN   NaN    204
# 207    NaN            Madison Scott                  NaN   NaN    205
# 208    NaN           Celeste Taylor                  NaN   NaN      -
# 209    NaN             Ella Fajardo                  NaN   NaN    207
# 210    NaN            Silvia Nativi                  NaN   NaN    208
# 211    NaN               Taya Davis                  NaN   NaN    209
# 212    NaN         Quinesha Lockett                  NaN   NaN      -
# 213    NaN            Anaya Peoples                  NaN   NaN    211
# 214    NaN            Kyla Hamilton                  NaN   NaN    212
# 215    NaN              Issy Morgan                  NaN   NaN      -
# 216    NaN           Kameryn Dorsey                  NaN   NaN    214
# 217    NaN           Jaddan Simmons                  NaN   NaN    215
# 218    NaN           Nakyah Terrell                  NaN   NaN      -
# 219    NaN            Gabby Gregory                  NaN   NaN    217
# 220    NaN               Grace Cave                  NaN   NaN    218
# 221    NaN          Domonique Davis                  NaN   NaN    219
# 222    NaN          O'Mariah Gordon                  NaN   NaN    221
# 223    NaN           Olivia  Porter                  NaN   NaN    222
# 224    NaN            Kennedi Grant                  NaN   NaN    223
# 225    NaN              Ella Sawyer                  NaN   NaN    224
# 226    NaN           Grace  Arnolie                  NaN   NaN    225
# 227    NaN          McKenzie Forbes                  NaN   NaN    226
# 228    NaN              Jada Walker                  NaN   NaN      -
# 229    NaN          Elena Rodriguez                  NaN   NaN    228
# 230    NaN      Nina De Leon Negron                  NaN   NaN    229
# 231    NaN                Gia Adams                  NaN   NaN    230
# 232    NaN              Jayla Adams                  NaN   NaN    232
# 233    NaN               Ainhoa Cea                  NaN   NaN    233
# 234    NaN             Alyssa Marin                  NaN   NaN      -
# 235    NaN         Alexis Hutchison                  NaN   NaN    235
# 236    NaN               Anne Simon                  NaN   NaN      -
# 237    NaN            Iyanna Warren                  NaN   NaN    237
# 238    NaN          Jiselle Woodson                  NaN   NaN    238
# 239    NaN       Chardonnay Hartley                  NaN   NaN    239
# 240    NaN     Sharonica Hartsfield                  NaN   NaN    240
# 241    NaN           Genesis Bryant                  NaN   NaN    241
# 242    NaN              Sidney Love                  NaN   NaN    242
# 243    NaN               Ivy Turner                  NaN   NaN      -
# 244    NaN             Amyah Reaves                  NaN   NaN    244
# 245    NaN               Delma Zita                  NaN   NaN    245
# 246    NaN             Paula Suarez                  NaN   NaN    246
# 247    NaN      Sh'Diamond McKnight                  NaN   NaN    247
# 248    NaN               Deja Kelly                  NaN   NaN    248
# 249    NaN                Liz Smith                  NaN   NaN    249
# 250    NaN             Sydney Burns                  NaN   NaN    250
#
#                   Team_y   Cl Height Position    G  AST  APG
# 0                   Iowa  Sr.    6-0        G   36  322  8.9
# 1    Southern California  Fr.    6-2        G   33  110  3.3
# 2              Villanova  Jr.    5-9        G   33  123  3.7
# 3                Buffalo  Sr.    5-8        G   33  108  3.3
# 4                    NaN  NaN    NaN      NaN  NaN  NaN  NaN
# 5             Notre Dame  Fr.    5-6        G   35  194  5.5
# 6                Wofford  Jr.    5-7        G   30  163  5.4
# 7               Syracuse  Sr.    5-5        G   32  114  3.6
# 8           Arkansas St.  Jr.    5-7        G   26   95  3.7
# 9           Colorado St.  Sr.    5-2        G   31  227  7.3
# 10                 Drake  Jr.    5-8        G   35  243  6.9
# 11         Virginia Tech  Sr.    5-6        G   32  218  6.8
# 12        Sacramento St.  So.    5-9        G   31  208  6.7
# 13              Missouri  Sr.    5-6        G   29  189  6.5
# 14                 UConn  Sr.   5-10        G   37  238  6.4
# 15              Marshall  Sr.    5-4        G   33  209  6.3
# 16           Saint Louis  Sr.   5-10        G   33  205  6.2
# 17                  Yale  Sr.    5-7        G   27  165  6.1
# 18       Mississippi St.  Sr.    5-3        G   35  213  6.1
# 19                Purdue  Sr.   5-11        G   33  197  6.0
# 20               Pacific  Jr.    5-9        G   34  201  5.9
# 21                  Utah  Jr.    5-6        G   34  200  5.9
# 22        Boston College  Jr.    5-8        G   33  191  5.8
# 23               Gonzaga  Sr.    5-8        G   36  208  5.8
# 24    Col. of Charleston  Sr.    5-6        G   31  178  5.7
# 25              Nebraska  Sr.    5-9        G   35  199  5.7
# 26       Ark.-Pine Bluff  Sr.    6-2        G   29  163  5.6
# 27          Gardner-Webb  Jr.    5-6        G   30  168  5.6
# 28          Northwestern  So.    5-9        G   30  167  5.6
# 29         Eastern Wash.  Sr.    5-9        G   34  189  5.6
# 30            Kansas St.  Jr.    6-1        G   34  189  5.6
# 31              Maryland  Jr.    6-2        G   32  177  5.5
# 32             Minnesota  So.   5-11        G   33  181  5.5
# 33             Green Bay  Jr.    5-7        G   34  185  5.4
# 34              Virginia  Fr.    5-7        G   32  172  5.4
# 35            Seton Hall  Sr.    5-9        G   30  160  5.3
# 36                   UAB  So.    5-5        G   32  170  5.3
# 37         West Virginia  So.    5-6        G   33  173  5.2
# 38              Richmond  Sr.    5-5        G   35  183  5.2
# 39          Michigan St.  Jr.    5-8        G   30  156  5.2
# 40          Georgia Tech  So.    5-9        G   33  170  5.2
# 41                 Siena  So.   5-10        G   30  154  5.1
# 42          Eastern Ill.  Jr.    5-8        G   33  169  5.1
# 43             San Diego  So.    5-9        G   31  158  5.1
# 44              Colorado  Sr.    5-7        G   34  172  5.1
# 45               Clemson  Sr.    5-7        G   31  156  5.0
# 46          Middle Tenn.  Sr.    5-6        G   35  176  5.0
# 47                 Texas  Fr.    6-1        F   37  185  5.0
# 48            Oregon St.  Jr.   5-11        G   35  175  5.0
# 49               Indiana  Sr.    6-0        G   32  160  5.0
# 50          South Dakota  Jr.    5-9        G   36  178  4.9
# 51           Santa Clara  So.   5-10        G   34  167  4.9
# 52             Princeton  Sr.    5-9        G   30  147  4.9
# 53        South Carolina  So.    5-8        G   35  171  4.9
# 54            California  Sr.    5-5        G   34  165  4.9
# 55                  UTSA  Sr.   5-10        G   33  160  4.8
# 56           USC Upstate  Sr.    5-7        G   31  150  4.8
# 57              Ball St.  Jr.    5-8            34  164  4.8
# 58              Iowa St.  Fr.    6-2        F   33  159  4.8
# 59           Stony Brook  Sr.    5-7        G   33  159  4.8
# 60                  Troy  Jr.   5-10        G   29  139  4.8
# 61             Milwaukee  So.    5-6        G   32  153  4.8
# 62              Ball St.  Jr.    5-7        G   34  162  4.8
# 63                  UNLV  Jr.    5-7        G   33  157  4.8
# 64             Marquette  Sr.    5-9        G   32  151  4.7
# 65         Bowling Green  Jr.    5-7        G   31  146  4.7
# 66                 Maine  Jr.   5-10        F   34  160  4.7
# 67             App State  Sr.    5-7        G   32  150  4.7
# 68            South Fla.  Sr.   5-10        G   33  154  4.7
# 69          Missouri St.  Jr.    5-4        G   33  153  4.6
# 70          Oklahoma St.  Jr.    5-8        G   30  139  4.6
# 71                Toledo  Sr.    5-7        G   34  157  4.6
# 72    California Baptist  Sr.    5-5        G   30  138  4.6
# 73              Duquesne  Jr.    5-7        G   34  155  4.6
# 74              Oklahoma  Sr.    5-3        G   33  150  4.5
# 75           Georgia St.  Fr.    5-5        G   30  136  4.5
# 76          Sacred Heart  So.    5-3        G   34  154  4.5
# 77               Liberty  Jr.    5-6        G   34  153  4.5
# 78            Binghamton  So.    5-7        G   31  139  4.5
# 79                  UCLA  So.   5-11        G   34  152  4.5
# 80            Vanderbilt  Sr.    5-9        G   33  147  4.5
# 81            Holy Cross  So.    5-8        G   34  151  4.4
# 82               Gonzaga  Sr.    5-9        G   35  153  4.4
# 83          Northeastern  Sr.    5-6        G   27  118  4.4
# 84               Georgia  Jr.    5-7        G   30  131  4.4
# 85            Murray St.  Sr.    5-8        G   32  139  4.3
# 86         San Francisco  Jr.    5-7        G   30  130  4.3
# 87    California Baptist  So.    5-9        G   24  104  4.3
# 88                   ULM  Sr.    5-8        G   34  147  4.3
# 89              Illinois  Sr.    5-6        G   29  125  4.3
# 90               Harvard  Jr.   5-10        G   23   99  4.3
# 91             Boise St.  Sr.   5-11        G   33  142  4.3
# 92              Canisius  Sr.    5-5        G   31  133  4.3
# 93            Georgetown  Sr.   5-10        G   35  149  4.3
# 94             Creighton  Sr.    5-7        G   32  136  4.2
# 95             Tennessee  Sr.    5-6        G   32  136  4.2
# 96           Eastern Ky.  Sr.    5-9        G   34  144  4.2
# 97            North Ala.  Sr.    5-4        G   30  127  4.2
# 98             Wisconsin  So.    5-4        G   31  131  4.2
# 99                Temple  Sr.    5-6        G   32  134  4.2
# 100         Illinois St.  Sr.    5-8        G   34  142  4.2
# 101          Florida St.  So.    5-8        G   33  137  4.2
# 102          Austin Peay  So.    5-7        G   33  136  4.1
# 103               Furman  Jr.    5-9        G   26  107  4.1
# 104         Oral Roberts  Sr.    5-7        G   32  131  4.1
# 105          Western Ky.  Jr.    5-5        G   32  131  4.1
# 106             Stanford  So.    5-7        G   34  139  4.1
# 107        Cleveland St.  Jr.    5-8        G   35  143  4.1
# 108         Morehead St.  Sr.    5-4        G   30  122  4.1
# 109                  NIU  Sr.    5-6        G   31  126  4.1
# 110             Columbia  Jr.   5-10        G   30  121  4.0
# 111     South Dakota St.  Jr.    5-6        G   30  121  4.0
# 112       Loyola Chicago  Sr.    5-8        G   31  125  4.0
# 113                  SFA  Sr.    5-9        G   34  136  4.0
# 114                 UCLA  Sr.    5-9        G   34  136  4.0
# 115          Norfolk St.  Jr.    5-8        G   33  132  4.0
# 116        Southern Ill.  Sr.    5-4        G   31  123  4.0
# 117             LMU (CA)  Sr.    5-5        G   30  119  4.0
# 118             Oklahoma  Jr.    6-1        G   32  126  3.9
# 119            Grambling  Jr.    5-7        G   28  110  3.9
# 120         UT Arlington  Sr.    6-1        F   33  129  3.9
# 121                  SMU  Sr.    5-8        G   30  117  3.9
# 122             Columbia  Jr.    6-0        G   30  117  3.9
# 123         N.C. Central  Sr.    5-4        G   30  117  3.9
# 124              Belmont  Jr.    5-7        G   35  136  3.9
# 125              Vermont  Sr.    5-8        G   35  136  3.9
# 126               Baylor  Sr.    5-6        G   34  132  3.9
# 127             Colorado  Jr.    5-9        G   34  131  3.9
# 128            Manhattan  So.   5-10        G   26  100  3.8
# 129            Texas A&M  Sr.    5-7        G   26  100  3.8
# 130    Abilene Christian  Jr.   5-10        G   30  115  3.8
# 131          Southern U.  Sr.    5-6        G   30  115  3.8
# 132               Tulane  Sr.    5-6        G   30  115  3.8
# 133        Western Caro.  Jr.    5-8        G   29  111  3.8
# 134               Auburn  Sr.    5-8        G   29  111  3.8
# 135          Jackson St.  Sr.    5-8        G   33  126  3.8
# 136                  FIU  Jr.    5-6        G   27  103  3.8
# 137           Evansville  So.    5-8        G   32  122  3.8
# 138                UConn  Sr.    6-0        G   37  141  3.8
# 139              Montana  Sr.    5-8        G   33  125  3.8
# 140                  UIC  Jr.    5-7        G   34  128  3.8
# 141             NC State  Jr.    6-1        G   34  128  3.8
# 142               Wagner  Sr.    5-7        G   25   94  3.8
# 143       Southern Miss.  Jr.    5-6        G   29  109  3.8
# 144             Ohio St.  Sr.   5-10        G   32  120  3.8
# 145          Wake Forest  Jr.    5-9        G   31  116  3.7
# 146                  BYU  Fr.   5-10        G   33  123  3.7
# 147               Drexel  Sr.   5-11        G   34  126  3.7
# 148                  UIC  Sr.    5-5        G   34  126  3.7
# 149               Lehigh  Jr.   5-10        G   27  100  3.7
# 150            Villanova  Sr.   5-10        G   33  122  3.7
# 151           Fresno St.  Fr.    5-6        G   33  122  3.7
# 152                  BYU  Sr.    5-8        G   32  118  3.7
# 153           Oregon St.  Fr.    6-0        G   35  129  3.7
# 154            Fairfield  Sr.   5-10        G   33  121  3.7
# 155       Tennessee Tech  Sr.    5-8        G   30  110  3.7
# 156                 Elon  Fr.    5-4        G   30  110  3.7
# 157       South Carolina  Sr.    5-9        G   35  128  3.7
# 158            UC Irvine  Sr.    5-7        G   32  117  3.7
# 159                  LSU  Sr.    5-7        G   32  117  3.7
# 160           New Mexico  Jr.    5-8        G   30  109  3.6
# 161        Western Mich.  Sr.    5-8        G   30  109  3.6
# 162             Marshall  Sr.    5-5        G   32  116  3.6
# 163          Utah Valley  Jr.    5-6        G   29  105  3.6
# 164                 Duke  Fr.    5-9        G   34  123  3.6
# 165              Arizona  Sr.    6-0        G   34  123  3.6
# 166        Bowling Green  Fr.    5-8        G   31  112  3.6
# 167            UT Martin  So.    6-1        F   31  112  3.6
# 168             American  Sr.   5-10        G   28  101  3.6
# 169              Buffalo  Sr.    5-3        G   33  119  3.6
# 170            Marquette  Sr.   5-11        G   32  115  3.6
# 171              Hofstra  Sr.    5-6        G   32  115  3.6
# 172            Fairfield  Sr.    5-6        G   33  118  3.6
# 173       North Carolina  Sr.    6-1        G   33  118  3.6
# 174        Southern Utah  Sr.    5-8        G   30  107  3.6
# 175         Morehead St.  Fr.    5-9        G   30  107  3.6
# 176                  LIU  Sr.    5-6        G   27   96  3.6
# 177           Miami (FL)  Jr.    5-6        G   31  110  3.5
# 178                  UNI  Jr.    5-6        G   31  110  3.5
# 179       UNC Greensboro  ---   5-11        G   33  117  3.5
# 180    Southeast Mo. St.  Jr.    5-7        G   28   99  3.5
# 181         Grand Canyon  Jr.   5-10        G   28   99  3.5
# 182         Presbyterian  So.    5-7        G   36  127  3.5
# 183                 Navy  Fr.    5-9        G   31  109  3.5
# 184           Pittsburgh  So.    5-7        G   31  109  3.5
# 185      St. John's (NY)  Jr.    5-6        G   33  116  3.5
# 186                 Rice  Sr.    5-9        G   34  119  3.5
# 187             Portland  Sr.    5-7        G   34  119  3.5
# 188       Youngstown St.  Sr.    5-7        G   32  112  3.5
# 189         Western Ill.  So.    5-9        G   30  105  3.5
# 190             La Salle  Sr.   5-10        G   30  105  3.5
# 191            Manhattan  So.    5-8        G   28   98  3.5
# 192             Arkansas  Jr.    5-9        G   33  115  3.5
# 193               Drexel  Sr.    6-0        F   34  118  3.5
# 194        Southern Utah  Sr.    6-0        G   30  104  3.5
# 195               Denver  So.    5-8        G   30  104  3.5
# 196          Georgia St.  Jr.    5-6        G   28   97  3.5
# 197       Washington St.  So.    5-9        G   28   97  3.5
# 198             NC State  Fr.   5-10        G   37  128  3.5
# 199             N.C. A&T  Jr.    5-9        G   34  117  3.4
# 200             Kentucky  Sr.   5-11        G   26   89  3.4
# 201               Towson  Sr.   5-10        G   31  106  3.4
# 202             Campbell  So.    5-7        G   31  106  3.4
# 203   California Baptist  So.    5-9        G   31  106  3.4
# 204                  UCF  Jr.   5-10        G   29   99  3.4
# 205               Dayton  Jr.    5-8        G   29   99  3.4
# 206         North Dakota  Sr.    5-9        G   27   92  3.4
# 207             Ole Miss  Sr.    6-1        F   32  109  3.4
# 208             Ohio St.  Sr.   5-11        G   32  109  3.4
# 209                 Iona  Jr.    5-5        G   30  102  3.4
# 210       Louisiana Tech  Jr.    6-0        G   33  112  3.4
# 211              Fordham  Jr.    5-7        G   28   95  3.4
# 212               Toledo  Sr.   5-10        G   28   95  3.4
# 213               DePaul  Sr.   5-10        G   31  105  3.4
# 214             Nicholls  Sr.    5-6        G   32  108  3.4
# 215             Davidson  Jr.   5-10        G   24   81  3.4
# 216   Saint Francis (PA)  Fr.    5-6        G   30  101  3.4
# 217          Arizona St.  Sr.    5-9        G   31  104  3.4
# 218           High Point  Jr.    5-6        G   31  104  3.4
# 219           Kansas St.  Sr.    6-0        G   34  114  3.4
# 220                Omaha  Jr.    5-7        G   29   97  3.3
# 221       Southern Miss.  Sr.    5-6        G   33  110  3.3
# 222          Florida St.  Jr.    5-4        G   34  113  3.3
# 223            Charlotte  So.    5-8        G   31  103  3.3
# 224                Omaha  Jr.    5-7        G   28   93  3.3
# 225          Indiana St.  Sr.    5-9        G   32  106  3.3
# 226                Brown  So.    5-8        G   27   89  3.3
# 227  Southern California  Sr.    6-0        G   34  112  3.3
# 228               Baylor  Jr.    5-7        G   34  112  3.3
# 229              Harvard  Jr.    6-2        G   24   79  3.3
# 230                  UIW  Sr.    5-6        G   29   95  3.3
# 231         UT Arlington  Jr.    5-7        G   33  108  3.3
# 232        North Florida  Sr.    5-6        G   30   98  3.3
# 233             Lipscomb  So.    5-6        G   28   91  3.2
# 234     UC Santa Barbara  Sr.    5-9        G   28   91  3.2
# 235           Wright St.  Sr.    5-7        G   33  107  3.2
# 236                Maine  Sr.    5-8        G   33  107  3.2
# 237               Howard  Sr.    5-3        G   29   94  3.2
# 238     Northwestern St.  Sr.    5-5        G   25   81  3.2
# 239              Niagara  So.    5-3        G   34  110  3.2
# 240                 Troy  Jr.    5-5        G   31  100  3.2
# 241             Illinois  Sr.    5-6        G   32  103  3.2
# 242                 UTSA  So.    5-8        G   33  106  3.2
# 243          Eastern Ky.  Sr.    5-4        G   33  106  3.2
# 244              Hampton  Jr.    5-7        G   24   77  3.2
# 245                 UTEP  Jr.    5-8        G   29   93  3.2
# 246         George Mason  Jr.    6-0        G   30   96  3.2
# 247     Mississippi Val.  Jr.    5-7        G   31   99  3.2
# 248       North Carolina  Sr.    5-8        G   33  105  3.2
# 249              Pacific  Sr.    5-9        G   28   89  3.2
# 250             UC Davis  Jr.    5-9        G   34  108  3.2

# %% [markdown]
# ## Data Analysis (Visualization)

# %%
# Show table sort by APG show Caitlyn Clark leads in APG
top_stats = merge_df[['Name','PPG','APG']].head(15)

print(top_stats.sort_values(by=['APG'],ascending=False,ignore_index=True).head(15))
# Out:
#                  Name   PPG  APG
# 0       Caitlin Clark  31.7  8.9
# 1   McKenna Hofschild  22.1  7.3
# 2     Katie Dinnebier   NaN  6.9
# 3      Georgia Amoore   NaN  6.8
# 4     Benthe Versteeg   NaN  6.7
# 5        Mama Dembele   NaN  6.5
# 6           Nika Muhl   NaN  6.4
# 7      Hannah Hidalgo  22.6  5.5
# 8        Rachael Rose  22.3  5.4
# 9          Lucy Olsen  23.4  3.7
# 10  Izzy Higginbottom  22.2  3.7
# 11       Dyaisha Fair  22.2  3.6
# 12       JuJu Watkins  27.0  3.3
# 13     Chellia Watson  23.0  3.3
# 14   Elizabeth Kitley  22.8  NaN

# %%
# Convert the columns to numeric types
top_stats['APG'] = pd.to_numeric(top_stats['APG'], errors='coerce')
top_stats['PPG'] = pd.to_numeric(top_stats['PPG'], errors='coerce')

# Create the scatter plot
ax = top_stats.plot(kind="scatter", x="APG", y="PPG", fontsize=25, figsize=(30,15))
ax.set_xlabel('Assists Per Game',fontsize = 40, color="red")
ax.set_ylabel("Points Per Game",fontsize = 40, color="red")
ax.set_title('Caitlyn Clarks Performance In Womens College Basketball',fontsize = 40, color="red")

# Annotate the points
for index, row in top_stats.iterrows():
    ax.annotate(row['Name'], (row['APG'], row['PPG']), fontsize=40)
